# %% [markdown]
# <a href="https://colab.research.google.com/github/kavitaraikwar07/Python/blob/main/openCV_operation_%26_Face_detection_with_openCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#INSTALLING OPENCV
import cv2
print(cv2.__version__)
# Out:
# 4.8.0

# %%
#BASIC OPENCV OPERATIONS

# %%
#READING AN IMAGE AND PRINTING ITS DIMENTIONS..
import cv2
image = cv2.imread('img_2.png')
x, y =image.shape[:2]
print("Height = {}, Width = {}".format(x, y))
# Out:
# Height = 1500, Width = 1000

# %%
#EXTRACTING RGB VALUES OF THE PIXELS
(R, G, B)= image[250,250]       #selecting the pixel at this location
print("R = {},G = {},B = {}".format(R, G, B))
B = image[250, 250, 0]
print("just the value of B = {}".format(B))
# Out:
# R = 229,G = 217,B = 205
# just the value of B = 229

# %%
#RESIZING THE IMAGE TO ANY DIMENSIONS..
size= cv2.resize(image,(1910,1000))
cv2.imwrite("img_2.png",image)
# Out:
# True

# %%
#PLACING A BOX AROUND ANY PIXEL
rectangle = cv2.rectangle(image, (1500, 500),(600, 400),(255,0,0), 2);
cv2.imwrite("img_2.png", image)
# Out:
# True

# %%
#ADDING TEXT TO THE SCREEN
text_input = cv2.putText(image, 'hello', (500, 500),cv2.FONT_HERSHEY_SIMPLEX, 4, (255, 0,0), 2)
cv2.imwrite("imgwithtext.png",image)
# Out:
# True

# %%
import imutils
from google.colab.patches import cv2_imshow
import cv2
image = cv2.imread("img_2.png")
(h, w, d) = image.shape
print("width={}, height={}, depth={}".format(w, h, d))
cv2_imshow(image)
# Out:
# width=1000, height=1500, depth=3
# <PIL.Image.Image image mode=RGB size=1000x1500>

# %%
#FACE DETECTION WITH PYTHON USING OPENCV

# %%
#import the opencv library
import cv2

# %%
#USING THE PRE-TRAINED CLASSIFIER FROM OPENCV
face_cascade = cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml') #Load the cascade

# %%
#UPLOAD THE IMPUT IMAGE
img = cv2.imread("img1.png") #Read the input image

# %%
#PERFORM FACE DETECTION
faces = face_cascade.detectMultiScale(img, 1.1, 4)  #detect faces

# %%
#DRAWING RECTANGLE AROUND THE FACES
for (x, y, w, h) in faces:
  cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
#Exporting the image file
#export the result
cv2.imwrite("face_detected.png",img)
print("Photo successfully exported")
# Out:
# Photo successfully exported
